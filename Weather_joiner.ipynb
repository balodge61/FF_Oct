# %%
import numpy as np
import pandas as pd

# %%
ht_df = pd.read_csv(r'C:\Users\cbi7088\Oct\Hash_table.csv')
weather_df = pd.read_csv(r'C:\Users\cbi7088\Oct\Weather.csv')
odds_df = pd.read_csv(r'C:\Users\cbi7088\Oct\Odds_17-19.csv',encoding = 'ISO-8859-1')

# %%
print(weather_df.shape)
weather_df.head()
# Out:
# (590, 13)
#       Away                     Game Unnamed: 2          Unnamed: 3      Home  \
# 0   Chiefs       Kansas_city_ntc120          @  New_england_6n_120  Patriots
# 1     Jets    New_york_j_white_n120          @  Buffalo_red_ntc120     Bills
# 2   Eagles      Philadelphia_6n_120          @            Redskins  Redskins
# 3  Raiders  Oakland_b_wstripe_n_120          @    Tennessee_ntc120    Titans
# 4  Jaguars      Jacksonville_6n_120          @      Houston_6n_120    Texans
#
#         Time (ET)   TV         Unnamed: 7           Forecast    Wind  \
# 0  Final: 42 - 27  NBC       Nclear-night          62f Clear  1m WSW
# 1  Final: 12 - 21  CBS  Partly-cloudy-day  61f Partly Cloudy  6m NNE
# 2  Final: 30 - 17  FOX          Clear-day          69f Clear  3m NNE
# 3  Final: 26 - 16  CBS          Clear-day          73f Clear   4m NE
# 4   Final: 29 - 7  CBS          Clear-day          80f Clear   4m NE
#
#   Unnamed: 10  Week  Year
# 0     Details     1  2017
# 1     Details     1  2017
# 2     Details     1  2017
# 3     Details     1  2017
# 4     Details     1  2017

# %%
print(odds_df.shape)
odds_df.head()
# Out:
# (576, 8)
#    Date & Time         Favorite  Spread    Underdog  Total   Money Odds  Week  \
# 0  9/5 8:20 ET       At Chicago    -3.0   Green Bay   46.5  -$165 +$145     1
# 1  9/8 1:03 ET     At Minnesota    -3.5     Atlanta   46.5  -$190 +$165     1
# 2  9/8 1:03 ET  At Philadelphia   -10.0  Washington   44.0  -$550 +$425     1
# 3  9/8 1:03 ET       At NY Jets    -2.5     Buffalo   41.0  -$145 +$125     1
# 4  9/8 1:03 ET        Baltimore    -7.0    At Miami   40.5  -$345 +$275     1
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019
